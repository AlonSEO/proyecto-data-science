# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import datetime

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
df = pd.read_csv('drive/MyDrive/MyDrive/Data/Temp_Provincias.csv', sep=';', decimal='.')

# %%
df.head()
# Out:
#         FECHA Provincia  T. Máxima  T.Mínima
# 0  01/01/2018    Madrid       11.6       3.6
# 1  02/01/2018    Madrid       13.4       7.5
# 2  03/01/2018    Madrid       13.5       7.6
# 3  04/01/2018    Madrid       13.7       7.8
# 4  05/01/2018    Madrid       11.5       5.8

# %%
df.FECHA=pd.to_datetime(df.FECHA, format="%d/%m/%Y")

# %%
df.set_index('FECHA').resample('W')

# %%
df.head()
# Out:
#        FECHA Provincia  T. Máxima  T.Mínima
# 0 2018-01-01    Madrid       11.6       3.6
# 1 2018-01-02    Madrid       13.4       7.5
# 2 2018-01-03    Madrid       13.5       7.6
# 3 2018-01-04    Madrid       13.7       7.8
# 4 2018-01-05    Madrid       11.5       5.8

# %%
df.columns
# Out:
# Index(['FECHA', 'Provincia', 'T. Máxima', 'T.Mínima'], dtype='object')

# %%
df = df.set_index('FECHA')
df.head()
# Out:
#            Provincia  T. Máxima  T.Mínima
# FECHA
# 2018-01-01    Madrid       11.6       3.6
# 2018-01-02    Madrid       13.4       7.5
# 2018-01-03    Madrid       13.5       7.6
# 2018-01-04    Madrid       13.7       7.8
# 2018-01-05    Madrid       11.5       5.8

# %%
malaga_df = df[df["Provincia"] == "Málaga"]
#df[valencia_df]

# %%
malaga_df.head()
# Out:
#            Provincia  T. Máxima  T.Mínima
# FECHA
# 2018-01-01    Málaga       22.7      10.8
# 2018-01-02    Málaga       20.2      11.5
# 2018-01-03    Málaga       21.6      12.7
# 2018-01-04    Málaga       22.4      12.8
# 2018-01-05    Málaga       20.7      13.8

# %%
malaga_df.columns
# Out:
# Index(['Provincia', 'T. Máxima', 'T.Mínima'], dtype='object')

# %%
malaga_df['Temp_Media'] = malaga_df[['T. Máxima','T.Mínima']].mean(axis=1)
malaga_df.head()
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
#            Provincia  T. Máxima  T.Mínima  Temp_Media
# FECHA
# 2018-01-01    Málaga       22.7      10.8       16.75
# 2018-01-02    Málaga       20.2      11.5       15.85
# 2018-01-03    Málaga       21.6      12.7       17.15
# 2018-01-04    Málaga       22.4      12.8       17.60
# 2018-01-05    Málaga       20.7      13.8       17.25

# %%
malaga_df.head()
# Out:
#            Provincia  T. Máxima  T.Mínima  Temp_Media
# FECHA
# 2018-01-01    Málaga       22.7      10.8       16.75
# 2018-01-02    Málaga       20.2      11.5       15.85
# 2018-01-03    Málaga       21.6      12.7       17.15
# 2018-01-04    Málaga       22.4      12.8       17.60
# 2018-01-05    Málaga       20.7      13.8       17.25

# %%
malaga_df['Temp_Media'].plot()

# %%
# create timeseries readable by fbprophet
ts = pd.DataFrame({'ds':malaga_df.index,'y':malaga_df.Temp_Media})
#ts['cap'] = 30000 # unused in linear growth
#ts['floor'] = 0 # unused in linear growth
ts.head()
# Out:
#                    ds      y
# FECHA
# 2018-01-01 2018-01-01  16.75
# 2018-01-02 2018-01-02  15.85
# 2018-01-03 2018-01-03  17.15
# 2018-01-04 2018-01-04  17.60
# 2018-01-05 2018-01-05  17.25

# %%
from fbprophet import Prophet
from fbprophet.plot import add_changepoints_to_plot
# instantiate the model and fit the timeseries
prophet = Prophet(changepoint_range=0.5,changepoint_prior_scale=0.5)
prophet.fit(ts)

# create a future data frame 
future = prophet.make_future_dataframe(periods=40, freq='W') #documentación para ver cómo poner semanas
forecast = prophet.predict(future)

# display the most critical output columns from the forecast
forecast[['ds','yhat','yhat_lower','yhat_upper']].head()

# plot
fig = prophet.plot(forecast)
a = add_changepoints_to_plot(fig.gca(),prophet,forecast)
#fig
# Out:
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.

# %%
forecast[['ds','yhat','yhat_lower','yhat_upper']].head()
# Out:
#           ds       yhat  yhat_lower  yhat_upper
# 0 2018-01-01  12.890129   10.412206   15.480001
# 1 2018-01-02  12.388482    9.759411   14.894766
# 2 2018-01-03  12.420267    9.916363   15.026982
# 3 2018-01-04  12.207209    9.774545   14.665760
# 4 2018-01-05  11.975230    9.487913   14.373154

# %%
forecast.tail()
# Out:
#              ds      trend  ...  multiplicative_terms_upper       yhat
# 1475 2022-09-04  20.125412  ...                         0.0  25.913410
# 1476 2022-09-11  20.124524  ...                         0.0  25.407231
# 1477 2022-09-18  20.123635  ...                         0.0  25.158440
# 1478 2022-09-25  20.122747  ...                         0.0  24.721321
# 1479 2022-10-02  20.121858  ...                         0.0  23.664176
#
# [5 rows x 19 columns]

# %%
# Guardamos el resultado en un fichero csv separado por comas. 
forecast.to_csv('temp_malaga.csv',  index=False, sep=";", decimal=",")
