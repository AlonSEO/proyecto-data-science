# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import datetime

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
df = pd.read_csv('drive/MyDrive/MyDrive/Data/casos_covid_provincia.csv', sep=';', decimal=',')

# %%
df.head()
# Out:
#         fecha  provincia  ...  num_casos_prueba_elisa  num_casos_prueba_desconocida
# 0  01/01/2020   Alicante  ...                       0                             0
# 1  01/01/2020   Albacete  ...                       0                             0
# 2  01/01/2020    Almeria  ...                       0                             0
# 3  01/01/2020      Avila  ...                       0                             0
# 4  01/01/2020  Barcelona  ...                       0                             0
#
# [5 rows x 8 columns]

# %%
df.columns
# Out:
# Index(['fecha', 'provincia', 'num_casos', 'num_casos_prueba_pcr',
#        'num_casos_prueba_test_ac', 'num_casos_prueba_ag',
#        'num_casos_prueba_elisa', 'num_casos_prueba_desconocida'],
#       dtype='object')

# %%
df.fecha=pd.to_datetime(df.fecha, format="%d/%m/%Y")

# %%
df.head()
# Out:
#        fecha  provincia  ...  num_casos_prueba_elisa  num_casos_prueba_desconocida
# 0 2020-01-01   Alicante  ...                       0                             0
# 1 2020-01-01   Albacete  ...                       0                             0
# 2 2020-01-01    Almeria  ...                       0                             0
# 3 2020-01-01      Avila  ...                       0                             0
# 4 2020-01-01  Barcelona  ...                       0                             0
#
# [5 rows x 8 columns]

# %%
malaga_df = df[df["provincia"] == "Malaga"]
malaga_df.head()
# Out:
#          fecha provincia  ...  num_casos_prueba_elisa  num_casos_prueba_desconocida
# 28  2020-01-01    Malaga  ...                       0                             0
# 81  2020-01-02    Malaga  ...                       0                             0
# 134 2020-01-03    Malaga  ...                       0                             0
# 187 2020-01-04    Malaga  ...                       0                             0
# 240 2020-01-05    Malaga  ...                       0                             0
#
# [5 rows x 8 columns]

# %%
malaga_df.columns
# Out:
# Index(['fecha', 'provincia', 'num_casos', 'num_casos_prueba_pcr',
#        'num_casos_prueba_test_ac', 'num_casos_prueba_ag',
#        'num_casos_prueba_elisa', 'num_casos_prueba_desconocida'],
#       dtype='object')

# %%
malaga_df2 = malaga_df.set_index('fecha').resample('W')[['num_casos']].sum()

# %%
malaga_df2.head()
# Out:
#             num_casos
# fecha
# 2020-01-05          0
# 2020-01-12          0
# 2020-01-19          0
# 2020-01-26          0
# 2020-02-02          0

# %%
malaga_df2['num_casos'].plot()

# %%
# create timeseries readable by fbprophet
ts = pd.DataFrame({'ds':malaga_df2.index,'y':malaga_df2.num_casos})
#ts['cap'] = 30000 # unused in linear growth
#ts['floor'] = 0 # unused in linear growth
ts.head()
# Out:
#                    ds  y
# fecha
# 2020-01-05 2020-01-05  0
# 2020-01-12 2020-01-12  0
# 2020-01-19 2020-01-19  0
# 2020-01-26 2020-01-26  0
# 2020-02-02 2020-02-02  0

# %%
from fbprophet import Prophet
from fbprophet.plot import add_changepoints_to_plot
# instantiate the model and fit the timeseries
prophet = Prophet(changepoint_range=0.5,changepoint_prior_scale=0.5)
prophet.fit(ts)

# create a future data frame 
future = prophet.make_future_dataframe(periods=30, freq='W') #documentación para ver cómo poner semanas
forecast = prophet.predict(future)

# display the most critical output columns from the forecast
forecast[['ds','yhat','yhat_lower','yhat_upper']].head()

# plot
fig = prophet.plot(forecast)
a = add_changepoints_to_plot(fig.gca(),prophet,forecast)
#fig
# Out:
# INFO:fbprophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.

# %%
forecast[['ds','yhat','yhat_lower','yhat_upper']].head()
# Out:
#           ds         yhat   yhat_lower   yhat_upper
# 0 2020-01-05  2234.977404   -79.327238  4788.844085
# 1 2020-01-12  3096.543146   889.809397  5438.236411
# 2 2020-01-19  2787.775305   435.640893  5290.059464
# 3 2020-01-26  1618.380697  -736.244638  4013.602626
# 4 2020-02-02   226.317432 -1958.588867  2574.499633

# %%
forecast.tail()
# Out:
#             ds        trend  ...  multiplicative_terms_upper         yhat
# 135 2022-08-07  4994.884249  ...                         0.0  5694.344823
# 136 2022-08-14  5030.045183  ...                         0.0  4925.347721
# 137 2022-08-21  5065.206118  ...                         0.0  4495.338645
# 138 2022-08-28  5100.367052  ...                         0.0  4293.113136
# 139 2022-09-04  5135.527987  ...                         0.0  4081.169032
#
# [5 rows x 16 columns]

# %%
forecast.set_index('ds')['trend'].plot()

# %%
from fbprophet.plot import add_changepoints_to_plot
a = add_changepoints_to_plot(fig.gca(),prophet,forecast)
fig

# %%
# Guardamos el resultado en un fichero csv separado por comas. 
forecast.to_csv('covid_malaga.csv',  index=False, sep=";", decimal=",")

# %%
# Guardamos el resultado en un fichero csv separado por comas. 
malaga_df2.to_csv('covid_malaga1.csv',  index=False, sep=",", decimal=",")
