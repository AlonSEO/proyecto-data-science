# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import datetime

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
df = pd.read_csv('drive/MyDrive/MyDrive/Data/casos_covid_provincia.csv', sep=';', decimal=',')

# %%
df.head()
# Out:
#         fecha  provincia  ...  num_casos_prueba_elisa  num_casos_prueba_desconocida
# 0  01/01/2020   Alicante  ...                       0                             0
# 1  01/01/2020   Albacete  ...                       0                             0
# 2  01/01/2020    Almeria  ...                       0                             0
# 3  01/01/2020      Avila  ...                       0                             0
# 4  01/01/2020  Barcelona  ...                       0                             0
#
# [5 rows x 8 columns]

# %%
df.columns
# Out:
# Index(['fecha', 'provincia', 'num_casos', 'num_casos_prueba_pcr',
#        'num_casos_prueba_test_ac', 'num_casos_prueba_ag',
#        'num_casos_prueba_elisa', 'num_casos_prueba_desconocida'],
#       dtype='object')

# %%
df.fecha=pd.to_datetime(df.fecha, format="%d/%m/%Y")

# %%
df.head()
# Out:
#        fecha  provincia  ...  num_casos_prueba_elisa  num_casos_prueba_desconocida
# 0 2020-01-01   Alicante  ...                       0                             0
# 1 2020-01-01   Albacete  ...                       0                             0
# 2 2020-01-01    Almeria  ...                       0                             0
# 3 2020-01-01      Avila  ...                       0                             0
# 4 2020-01-01  Barcelona  ...                       0                             0
#
# [5 rows x 8 columns]

# %%
valencia_df = df[df["provincia"] == "Valencia"]
valencia_df.head()
# Out:
#          fecha provincia  ...  num_casos_prueba_elisa  num_casos_prueba_desconocida
# 48  2020-01-01  Valencia  ...                       0                             0
# 101 2020-01-02  Valencia  ...                       0                             0
# 154 2020-01-03  Valencia  ...                       0                             0
# 207 2020-01-04  Valencia  ...                       0                             0
# 260 2020-01-05  Valencia  ...                       0                             0
#
# [5 rows x 8 columns]

# %%
valencia_df.columns
# Out:
# Index(['fecha', 'provincia', 'num_casos', 'num_casos_prueba_pcr',
#        'num_casos_prueba_test_ac', 'num_casos_prueba_ag',
#        'num_casos_prueba_elisa', 'num_casos_prueba_desconocida'],
#       dtype='object')

# %%
valencia_df2 = valencia_df.set_index('fecha').resample('W')[['num_casos']].sum()

# %%
valencia_df2.head()
# Out:
#             num_casos
# fecha
# 2020-01-05          0
# 2020-01-12          0
# 2020-01-19          0
# 2020-01-26          0
# 2020-02-02          1

# %%
valencia_df2['num_casos'].plot()

# %%
# create timeseries readable by fbprophet
ts = pd.DataFrame({'ds':valencia_df2.index,'y':valencia_df2.num_casos})
#ts['cap'] = 30000 # unused in linear growth
#ts['floor'] = 0 # unused in linear growth
ts.head()
# Out:
#                    ds  y
# fecha
# 2020-01-05 2020-01-05  0
# 2020-01-12 2020-01-12  0
# 2020-01-19 2020-01-19  0
# 2020-01-26 2020-01-26  0
# 2020-02-02 2020-02-02  1

# %%
from fbprophet import Prophet
from fbprophet.plot import add_changepoints_to_plot
# instantiate the model and fit the timeseries
prophet = Prophet(changepoint_range=0.5,changepoint_prior_scale=0.5)
prophet.fit(ts)

# create a future data frame 
future = prophet.make_future_dataframe(periods=30, freq='W') #documentación para ver cómo poner semanas
forecast = prophet.predict(future)

# display the most critical output columns from the forecast
forecast[['ds','yhat','yhat_lower','yhat_upper']].head()

# plot
fig = prophet.plot(forecast)
a = add_changepoints_to_plot(fig.gca(),prophet,forecast)
#fig
# Out:
# INFO:fbprophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.

# %%
forecast[['ds','yhat','yhat_lower','yhat_upper']].head()
# Out:
#           ds         yhat    yhat_lower    yhat_upper
# 0 2020-01-05 -5406.773647 -10088.860715   -713.215144
# 1 2020-01-12  5679.359642   1010.035489  10312.366379
# 2 2020-01-19  9807.882773   4968.327029  14503.773914
# 3 2020-01-26  6380.691073   1774.617022  10940.212487
# 4 2020-02-02  -528.071957  -5299.849415   4460.034168

# %%
forecast.tail()
# Out:
#             ds         trend  ...  multiplicative_terms_upper          yhat
# 135 2022-08-07  32277.874525  ...                         0.0  27983.516150
# 136 2022-08-14  32747.392093  ...                         0.0  27462.381440
# 137 2022-08-21  33216.909661  ...                         0.0  27359.130152
# 138 2022-08-28  33686.427229  ...                         0.0  26933.066586
# 139 2022-09-04  34155.944797  ...                         0.0  26081.697156
#
# [5 rows x 16 columns]

# %%
forecast.set_index('ds')['trend'].plot()

# %%
from fbprophet.plot import add_changepoints_to_plot
a = add_changepoints_to_plot(fig.gca(),prophet,forecast)
fig

# %%
# Guardamos el resultado en un fichero csv separado por comas. 
forecast.to_csv('covid_valencia.csv',  index=False, sep=";", decimal=",")

# %%
# Guardamos el resultado en un fichero csv separado por comas. 
valencia_df2.to_csv('covid_valencia1.csv',  index=False, sep=",", decimal=",")
